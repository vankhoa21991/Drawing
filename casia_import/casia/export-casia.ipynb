# %%
from os.path import isdir
from unittest import TestCase

from PIL import Image

from pycasia import CASIA
import struct
from codecs import decode
from scipy.misc import toimage
import numpy as np
import os
import matplotlib.pyplot as plt
import _pickle as pickle
from casia import *

# %%
folder = "/mnt/DATA/lupin/Dataset/CASIA_HW1.0/"
IMGS, LBLS = extract_casia_offline(folder)

# %%
len(set(LBLS))
len(LBLS)
# Out:
# 1680258

# %%
from collections import Counter
Counter(LBLS)
# Out:
# Counter({'!\x00': 416,
#          '"\x00': 415,
#          '#\x00': 416,
#          '$\x00': 413,
#          '%\x00': 415,
#          '&\x00': 408,
#          '(\x00': 416,
#          ')\x00': 415,
#          '*\x00': 403,
#          '+\x00': 416,
#          ',\x00': 416,
#          '-\x00': 416,
#          '.\x00': 417,
#          '/\x00': 416,
#          '0\x00': 416,
#          '1\x00': 417,
#          '2\x00': 415,
#          '3\x00': 416,
#          '4\x00': 413,
#          '5\x00': 417,
#          '6\x00': 416,
#          '7\x00': 416,
#          '8\x00': 417,
#          '9\x00': 416,
#          ':\x00': 416,
#          ';\x00': 417,
#          '<\x00': 416,
#          '=\x00': 417,
#          '>\x00': 415,
#          '?\x00': 413,
#          '@\x00': 413,
#          'A\x00': 416,
#          'B\x00': 416,
#          'C\x00': 416,
#          'D\x00': 416,
#          'E\x00': 415,
#          'F\x00': 416,
#          'G\x00': 416,
#          'H\x00': 416,
#          'I\x00': 417,
# ...

# %%
folder1 = "/mnt/DATA/lupin/Dataset/CASIA_HW1.1/Data/"
IMGS1, LBLS1 = extract_casia_offline(folder1)

# %%
from collections import Counter
print(len(set(LBLS1)))
print(len((LBLS1)))
Counter(LBLS1)
# Out:
# 3912
# 1172907
# Counter({'!\x00': 299,
#          '"\x00': 298,
#          '#\x00': 298,
#          '$\x00': 297,
#          '%\x00': 299,
#          '&\x00': 296,
#          '(\x00': 299,
#          ')\x00': 299,
#          '*\x00': 296,
#          '+\x00': 298,
#          ',\x00': 299,
#          '-\x00': 299,
#          '.\x00': 299,
#          '/\x00': 299,
#          '0\x00': 298,
#          '1\x00': 299,
#          '2\x00': 298,
#          '3\x00': 298,
#          '4\x00': 297,
#          '5\x00': 299,
#          '6\x00': 297,
#          '7\x00': 298,
#          '8\x00': 298,
#          '9\x00': 299,
#          ':\x00': 295,
#          ';\x00': 298,
#          '<\x00': 299,
#          '=\x00': 299,
#          '>\x00': 298,
#          '?\x00': 299,
#          '@\x00': 298,
#          'A\x00': 299,
#          'B\x00': 298,
#          'C\x00': 299,
#          'D\x00': 298,
#          'E\x00': 298,
#          'F\x00': 299,
#          'G\x00': 299,
#          'H\x00': 300,
# ...

# %%
folder2 = "/mnt/DATA/lupin/Dataset/CASIA_HW1.2/"
IMGS2, LBLS2 = extract_casia_offline(folder2)
# Out:
# error at :767-f.gnt

# %%
print(len(set(LBLS2)))
print(len((LBLS2)))
Counter(LBLS2)
# Out:
# 3056
# 1038612
# Counter({'!\x00': 294,
#          '"\x00': 294,
#          '#\x00': 297,
#          '$\x00': 296,
#          '%\x00': 295,
#          '&\x00': 294,
#          '(\x00': 297,
#          ')\x00': 297,
#          '*\x00': 294,
#          '+\x00': 297,
#          ',\x00': 299,
#          '-\x00': 298,
#          '.\x00': 297,
#          '/\x00': 296,
#          '0\x00': 296,
#          '1\x00': 297,
#          '2\x00': 296,
#          '3\x00': 297,
#          '4\x00': 296,
#          '5\x00': 296,
#          '6\x00': 296,
#          '7\x00': 294,
#          '8\x00': 295,
#          '9\x00': 295,
#          ':\x00': 295,
#          ';\x00': 298,
#          '<\x00': 298,
#          '=\x00': 298,
#          '>\x00': 298,
#          '?\x00': 295,
#          '@\x00': 296,
#          'A\x00': 297,
#          'B\x00': 296,
#          'C\x00': 297,
#          'D\x00': 297,
#          'E\x00': 296,
#          'F\x00': 296,
#          'G\x00': 295,
#          'H\x00': 297,
# ...

# %%
LB = LBLS + LBLS1 + LBLS2

# %%
print(len(set(LB)))
# Out:
# 6920

# %%
folder = "/mnt/DATA/lupin/Dataset/CASIA_OLHW1.0/Data/"
extract_casia_online(folder)
# Out:
# Extracting 400.pot
# Extracting 274.pot
# Extracting 170.pot
# Extracting 075.pot
# Extracting 141.pot
# Extracting 353.pot
# Extracting 124.pot
# Extracting 262.pot
# Extracting 326.pot
# Extracting 107.pot
# Extracting 302.pot
# Extracting 375.pot
# Extracting 056.pot
# Extracting 222.pot
# Extracting 312.pot
# Extracting 080.pot
# Extracting 284.pot
# Extracting 097.pot
# Extracting 077.pot
# Extracting 398.pot
# Extracting 143.pot
# Extracting 043.pot
# Extracting 384.pot
# Extracting 308.pot
# Extracting 290.pot
# Extracting 275.pot
# Extracting 026.pot
# Extracting 332.pot
# Extracting 062.pot
# Extracting 037.pot
# Extracting 314.pot
# Extracting 118.pot
# Extracting 133.pot
# Extracting 354.pot
# Extracting 403.pot
# Extracting 183.pot
# Extracting 348.pot
# Extracting 299.pot
# Extracting 305.pot
# Extracting 336.pot
# Extracting 278.pot
# Extracting 401.pot
# Extracting 294.pot
# Extracting 096.pot
# Extracting 120.pot
# Extracting 243.pot
# Extracting 072.pot
# ...

# %%
folder = "/mnt/DATA/lupin/Dataset/CASIA_OLHW1.1/Data/"
extract_casia_online(folder)
# Out:
# Extracting 1192.pot
# Extracting 1294.pot
# Extracting 1002.pot
# Extracting 1049.pot
# Extracting 1267.pot
# Extracting 1167.pot
# Extracting 1013.pot
# Extracting 1183.pot
# Extracting 1222.pot
# Extracting 1169.pot
# Extracting 1283.pot
# Extracting 1184.pot
# Extracting 1106.pot
# Extracting 1090.pot
# Extracting 1212.pot
# Extracting 1209.pot
# Extracting 1104.pot
# Extracting 1152.pot
# Extracting 1281.pot
# Extracting 1276.pot
# Extracting 1060.pot
# Extracting 1030.pot
# Extracting 1126.pot
# Extracting 1127.pot
# Extracting 1046.pot
# Extracting 1063.pot
# Extracting 1111.pot
# Extracting 1179.pot
# Extracting 1008.pot
# Extracting 1141.pot
# Extracting 1077.pot
# Extracting 1160.pot
# Extracting 1238.pot
# Extracting 1123.pot
# Extracting 1078.pot
# Extracting 1220.pot
# Extracting 1263.pot
# Extracting 1230.pot
# Extracting 1131.pot
# Extracting 1103.pot
# Extracting 1280.pot
# Extracting 1291.pot
# Extracting 1087.pot
# Extracting 1153.pot
# Extracting 1079.pot
# ...

# %%
folder = "/mnt/DATA/lupin/Dataset/CASIA_OLHW1.2/"
extract_casia_online(folder)
# Out:
# Extracting 513.pot
# Extracting 657.pot
# Extracting 737.pot
# Extracting 702.pot
# Extracting 745.pot
# Extracting 783.pot
# Extracting 705.pot
# Extracting 585.pot
# Extracting 514.pot
# Extracting 789.pot
# Extracting 512.pot
# Extracting 776.pot
# Extracting 515.pot
# Extracting 756.pot
# Extracting 635.pot
# Extracting 651.pot
# Extracting 757.pot
# Extracting 647.pot
# Extracting 546.pot
# Extracting 670.pot
# Extracting 574.pot
# Extracting 560.pot
# Extracting 684.pot
# Extracting 680.pot
# Extracting 521.pot
# Extracting 791.pot
# Extracting 704.pot
# Extracting 709.pot
# Extracting 692.pot
# Extracting 767.pot
# Extracting 579.pot
# Extracting 570.pot
# Extracting 677.pot
# Extracting 689.pot
# Extracting 608.pot
# Extracting 625.pot
# Extracting 665.pot
# Extracting 575.pot
# Extracting 510.pot
# Extracting 691.pot
# Extracting 661.pot
# Extracting 685.pot
# Extracting 676.pot
# Extracting 796.pot
# Extracting 729.pot
# Extracting 710.pot
# Extracting 520.pot
# ...
